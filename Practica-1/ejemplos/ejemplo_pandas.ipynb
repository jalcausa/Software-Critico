# %%
# %pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: six>=1.5 in d:\daniel\varios\pr1_dsc_ml\env3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# https://www.geeksforgeeks.org/python-pandas-dataframe/
import pandas as pd
import matplotlib.pyplot as plt

# making data frame from csv file
df = pd.read_csv("nba.csv", index_col ="Name")

# %%
df
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0
# ...                          ...        ...
# Shelvin Mack              Butler  2433333.0
# Raul Neto                    NaN   900000.0
# Tibor Pleiss                 NaN  2900000.0
# Jeff Withey               Kansas   947276.0
# NaN                          NaN        NaN
#
# [458 rows x 8 columns]

# %%
df.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df['Weight'].plot(label='weight')
plt.legend()

# %%
# select two columns
df2=df[['Team', 'Number']]

# %%
df2
# Out:
#                          Team  Number
# Name
# Avery Bradley  Boston Celtics     0.0
# Jae Crowder    Boston Celtics    99.0
# John Holland   Boston Celtics    30.0
# R.J. Hunter    Boston Celtics    28.0
# Jonas Jerebko  Boston Celtics     8.0
# ...                       ...     ...
# Shelvin Mack        Utah Jazz     8.0
# Raul Neto           Utah Jazz    25.0
# Tibor Pleiss        Utah Jazz    21.0
# Jeff Withey         Utah Jazz    24.0
# NaN                       NaN     NaN
#
# [458 rows x 2 columns]

# %%
# rows 0 to 2, all columns
df3 = df.iloc[0:3, :]
print(df3.head())
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN

# %%
# retrieving row by loc method
first = df.loc["Avery Bradley"]
second = df.loc["R.J. Hunter"]

# %%
first
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
# iterating rows and specific column
for i in range(len(df)):
  print(df.iat[i,0])
# Out:
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Boston Celtics
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# Brooklyn Nets
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# New York Knicks
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Philadelphia 76ers
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Toronto Raptors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Golden State Warriors
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Clippers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Los Angeles Lakers
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Phoenix Suns
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Sacramento Kings
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Chicago Bulls
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Cleveland Cavaliers
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Detroit Pistons
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Indiana Pacers
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Milwaukee Bucks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Dallas Mavericks
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Houston Rockets
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# Memphis Grizzlies
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# New Orleans Pelicans
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# San Antonio Spurs
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Atlanta Hawks
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Charlotte Hornets
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Miami Heat
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Orlando Magic
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Washington Wizards
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Denver Nuggets
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Minnesota Timberwolves
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Oklahoma City Thunder
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Portland Trail Blazers
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# Utah Jazz
# nan

# %%
# sort
print(df.sort_values(by='Name', ascending = True))
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Aaron Brooks             Chicago Bulls     0.0       PG  31.0    6-0   161.0
# Aaron Gordon             Orlando Magic     0.0       PF  20.0    6-9   220.0
# Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6   210.0
# Adreian Payne   Minnesota Timberwolves    33.0       PF  25.0   6-10   237.0
# Al Horford               Atlanta Hawks    15.0        C  30.0   6-10   245.0
# ...                                ...     ...      ...   ...    ...     ...
# Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3   180.0
# Zach LaVine     Minnesota Timberwolves     8.0       PG  21.0    6-5   189.0
# Zach Randolph        Memphis Grizzlies    50.0       PF  34.0    6-9   260.0
# Zaza Pachulia         Dallas Mavericks    27.0        C  32.0   6-11   275.0
# NaN                                NaN     NaN      NaN   NaN    NaN     NaN
#
#                        College      Salary
# Name
# Aaron Brooks            Oregon   2250000.0
# Aaron Gordon           Arizona   4171680.0
# Aaron Harrison        Kentucky    525093.0
# Adreian Payne   Michigan State   1938840.0
# Al Horford             Florida  12000000.0
# ...                        ...         ...
# Xavier Munford    Rhode Island         NaN
# Zach LaVine               UCLA   2148360.0
# Zach Randolph   Michigan State   9638555.0
# Zaza Pachulia              NaN   5200000.0
# NaN                        NaN         NaN
#
# [458 rows x 8 columns]

# %%
# filtering
df[df["Age"] > 30]
# Out:
#                                    Team  Number Position   Age Height  Weight  \
# Name
# Jarrett Jack              Brooklyn Nets     2.0       PG  32.0    6-3   200.0
# Lou Amundson            New York Knicks    17.0       PF  33.0    6-9   220.0
# Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8   240.0
# Jose Calderon           New York Knicks     3.0       PG  34.0    6-3   200.0
# Sasha Vujacic           New York Knicks    18.0       SG  32.0    6-7   195.0
# ...                                 ...     ...      ...   ...    ...     ...
# Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9   212.0
# Nick Collison     Oklahoma City Thunder     4.0       PF  35.0   6-10   255.0
# Randy Foye        Oklahoma City Thunder     6.0       SG  32.0    6-4   213.0
# Nazr Mohammed     Oklahoma City Thunder    13.0        C  38.0   6-10   250.0
# Chris Kaman      Portland Trail Blazers    35.0        C  34.0    7-0   265.0
#
#                           College      Salary
# Name
# Jarrett Jack         Georgia Tech   6300000.0
# Lou Amundson                 UNLV   1635476.0
# Carmelo Anthony          Syracuse  22875000.0
# Jose Calderon                 NaN   7402812.0
# Sasha Vujacic                 NaN    947276.0
# ...                           ...         ...
# Tayshaun Prince          Kentucky    947276.0
# Nick Collison              Kansas   3750000.0
# Randy Foye              Villanova   3135000.0
# Nazr Mohammed            Kentucky    222888.0
# Chris Kaman      Central Michigan   5016000.0
#
# [91 rows x 8 columns]

# %%
# New column
df['FromKentucky'] = df["College"] == "Kentucky"

# %%
df
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary  FromKentucky
# Name
# Avery Bradley              Texas  7730337.0         False
# Jae Crowder            Marquette  6796117.0         False
# John Holland   Boston University        NaN         False
# R.J. Hunter        Georgia State  1148640.0         False
# Jonas Jerebko                NaN  5000000.0         False
# ...                          ...        ...           ...
# Shelvin Mack              Butler  2433333.0         False
# Raul Neto                    NaN   900000.0         False
# Tibor Pleiss                 NaN  2900000.0         False
# Jeff Withey               Kansas   947276.0         False
# NaN                          NaN        NaN         False
#
# [458 rows x 9 columns]

# %%
# statistical
res = df[["Age", "Salary"]].mean()
print(res)

print(df[["Age"]].min())
print(df[["Age"]].max())
# Out:
# Age       2.693873e+01
# Salary    4.842684e+06
# dtype: float64
# Age    19.0
# dtype: float64
# Age    40.0
# dtype: float64
